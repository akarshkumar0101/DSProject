# %%
from U_Net_model import unet
from Prediction import prediction
import IPython.display as ipd


weights_path = '/Users/prajwal/Desktop/test/Train/weights'
model = unet()
audio_input_prediction = ['/Users/prajwal/Desktop/test/output/input_noisyvoice.wav']
sample_rate = 8000
min_duration = 1
frame_length = 8064
hop_length_frame = 8064
n_fft = 255
hop_length_fft = 63

denoised_data = prediction(weights_path, model, audio_input_prediction, sample_rate, 
                           min_duration, frame_length, hop_length_frame, n_fft, hop_length_fft)


ipd.Audio(data = denoised_data[0], rate = denoised_data[1] )
# Out:
# Loaded model from disk
# 128
# (1, 128, 128)
# (1, 128, 128)
# 8064
# 63
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
