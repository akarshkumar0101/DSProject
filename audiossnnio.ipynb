# %%
import torch
from torch.utils import data

# %%
ds = AudioSSDS(sr=8000, duration=5.0, sources=('datasets/voices_sr8000_dur5.npy', 'datasets/noises_sr8000_dur5.npy'))

# %%
params = {'batch_size': 1000,
          'shuffle': True,
          'num_workers': 0}

data_loader = data.DataLoader(ds, **params)

for x, y in gen:
    print(x.shape)
    x = x.numpy()
    y = y.numpy()
    ds.show_and_play_audio(x[0, :])
    ds.show_and_play_audio(y[0, 0, :])
# Out:
# torch.Size([1000, 40000])
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# torch.Size([1000, 40000])
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# torch.Size([703, 40000])
# ...

# %%
gc.collect()
# Out:
# 41999
