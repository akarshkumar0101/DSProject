# %%
import pandas as pd
from data_prep import create_data
from data_tools import audio_to_audio_frame_stack
import librosa 
data = pd.read_csv('UrbanSound8K/metadata/UrbanSound8K.csv')
data.head(5)
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
#folder containing noises
noise_dir = "/Users/prajwal/Desktop/test/UrbanSound8k/audio"
#folder containing clean voices
voice_dir = "/Users/prajwal/Desktop/test/LibriSpeech/dev-clean"
#path to save time series
path_save_time_serie = "/Users/prajwal/Desktop/test/Train/time_serie"
#path to save sounds
path_save_sound = "/Users/prajwal/Desktop/test/Train/sound"
#path to save spectrograms
path_save_spectrogram = "/Users/prajwal/Desktop/test/Train/spectrogram"
# Sample rate to read audio
sample_rate = 8000
# Minimum duration of audio files to consider
min_duration = 1.5
#Frame length for training data
frame_length = 8064
# hop length for clean voice files
hop_length_frame = 8064
# hop length for noise files
hop_length_frame_noise = 5000
# How much frame to create for training
nb_samples = 5000
#nb of points for fft(for spectrogram computation)
n_fft = 255
#hop length for fft
hop_length_fft = 63

create_data(noise_dir, voice_dir, path_save_time_serie, path_save_sound, path_save_spectrogram, sample_rate,
                   min_duration, frame_length, hop_length_frame, hop_length_frame_noise, nb_samples, n_fft, hop_length_fft)
# Out:
# 2703
# 8732
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/18453-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/156893-7-6-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/23131-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/165775-7-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/4911-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/203128-3-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/34621-4-13-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/34621-4-11-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/76091-6-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/23131-3-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/160092-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/156893-7-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/34621-4-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/145608-6-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/162541-1-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/147672-3-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/156893-7-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/179866-1-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/34621-4-15-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/4201-3-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/94401-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/76091-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/149177-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/76091-6-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/34621-4-17-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/4201-3-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/156893-7-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/145608-6-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/76090-6-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/23131-3-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/159710-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/102104-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/76091-6-5-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/46655-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/34621-4-5-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/34621-4-7-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/77751-4-7-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/165775-7-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/58202-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/34621-4-12-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/4201-3-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/34621-4-16-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/76091-6-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/76090-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/23131-3-5-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/147672-3-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/162541-1-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/145608-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/33849-3-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/145577-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/179866-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/156893-7-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/33849-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/34621-4-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/162541-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/145608-6-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/72567-1-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/163460-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/147672-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/76091-6-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/4201-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/76089-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/115537-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/34621-4-14-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/113785-3-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/34621-4-18-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/34621-4-25-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/108187-3-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/132073-1-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/34621-4-27-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/17307-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/158607-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/71080-4-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/132073-1-5-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/176634-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/155129-1-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/156893-7-9-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/108187-3-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/34621-4-21-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/22347-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/132073-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/73623-7-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/34621-4-26-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/34621-4-24-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/113785-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/132073-1-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/108187-3-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/185800-4-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/175844-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/156893-7-8-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/156893-7-10-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/155129-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/34621-4-8-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/132073-1-6-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/34621-4-20-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/34621-4-22-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/179864-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/132073-1-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold2/71080-4-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/162432-6-14-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/118440-4-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/39533-4-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/139948-3-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/197243-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/205874-4-9-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/118440-4-6-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/165774-7-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/179861-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/162432-6-12-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/162432-6-8-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/65472-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/43787-3-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/145611-6-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/165774-7-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/139948-3-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/118440-4-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/145609-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/26184-5-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/165774-7-6-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/118440-4-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/205874-4-10-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/145611-6-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/43787-3-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/7066-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/162432-6-10-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/26177-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/118440-4-7-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/205874-4-8-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/145611-6-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/197243-3-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/52102-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/45256-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/131199-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/118440-4-5-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/145611-6-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/205874-4-11-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/118440-4-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/165774-7-7-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/26177-1-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/162432-6-11-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/162432-6-9-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/162432-6-13-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/118440-4-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/145609-6-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/165774-7-5-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/26184-5-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/43787-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/145611-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/66587-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/159754-8-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/148841-6-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/99185-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/162432-6-5-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/84699-4-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/162432-6-7-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/159754-8-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/66587-3-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/93139-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/121299-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/37869-3-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/71439-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/100032-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/46391-1-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/116163-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/21187-5-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/162432-6-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/196071-2-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/185436-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/116163-3-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/162432-6-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/84699-4-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/205874-4-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/19503-3-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/71439-1-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/178260-7-7-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/43803-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/185436-1-5-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/20285-3-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/84254-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/162432-6-6-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/205874-4-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/66587-3-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/165774-7-8-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/159754-8-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/66587-3-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/162432-6-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/84699-4-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/164667-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/185436-1-7-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/77509-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/162432-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/71439-1-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/187920-7-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/205874-4-5-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/175849-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/118440-4-8-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/37869-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/71439-1-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/185436-1-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/162432-6-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/77247-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold5/116163-3-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/175855-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/50618-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/171249-1-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/165785-4-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/171305-7-14-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/171305-7-16-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/165785-4-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/171305-7-9-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/140824-4-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/24652-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/151877-5-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/22883-7-9-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/203956-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/47926-3-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/35629-3-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/85544-3-5-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/22883-7-81-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/47926-3-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/187356-1-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/171305-7-10-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/22883-7-67-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/171305-7-17-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/165785-4-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/121888-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/171249-1-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/171249-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/22883-7-27-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/22883-7-62-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/165785-4-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/165785-4-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/171305-7-11-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/47926-3-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/187356-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/175846-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/22883-7-64-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/176003-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/171305-7-13-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/22883-7-40-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/159176-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/47926-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/148837-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/344-3-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/22883-7-34-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/7064-6-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/38231-3-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/162435-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/162435-6-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/24632-6-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/148837-6-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/171305-7-20-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/23161-6-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/22883-7-77-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/135528-6-8-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/171305-7-6-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/161010-1-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/7064-6-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/156868-8-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/30832-3-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/196080-2-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/7064-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/156868-8-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/22883-7-91-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/117536-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/35296-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/22883-7-48-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/44278-1-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/68389-3-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/156868-8-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/24632-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/162435-6-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/38231-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/171305-7-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/23161-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/171305-7-21-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/148837-6-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/30832-3-12-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/179862-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/344-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/162435-6-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/22883-7-69-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/118964-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/161010-1-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/22883-7-28-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/22883-7-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/156868-8-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/7064-6-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/344-3-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/44278-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/35799-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/113160-8-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/155320-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/22883-7-33-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/115535-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/135528-6-9-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/68389-3-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/159752-8-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/156868-8-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold4/7064-6-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/148838-6-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/18594-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/34708-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/188824-7-11-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/155309-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/148838-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/18594-1-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/161195-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/188824-7-5-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/188824-7-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/18594-1-6-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/135526-6-13-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/162431-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/90846-8-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/175847-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/162431-6-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/18594-1-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/103199-4-6-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/188824-7-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/128030-3-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/118961-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/34708-6-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/175854-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/18594-1-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/188824-7-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/148838-6-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/188824-7-10-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/34708-6-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/188824-7-6-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/18594-1-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/160093-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/162431-6-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/144885-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/34708-6-5-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/128030-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/18594-1-5-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/188824-7-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/128030-3-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/188824-7-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/162431-6-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/20841-3-6-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/151359-1-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/151359-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/44831-3-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/179863-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/49809-3-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/20841-3-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/76094-6-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/118496-1-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/49809-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/12647-3-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/118070-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/188824-7-8-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/20841-3-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/135526-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/12647-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/170015-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/179865-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/151359-1-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/76094-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/156418-3-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/49769-5-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/200161-3-7-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/52357-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/151359-1-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/19338-5-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/207124-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/44831-3-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/135526-6-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/20841-3-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/12647-3-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/32417-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold3/118496-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/145206-6-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/103076-3-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/107090-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/145206-6-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/50668-5-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/113203-5-7-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/171464-3-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/145206-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/103076-3-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/33340-7-9-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/98536-8-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/145206-6-5-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/168037-4-11-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/162433-6-8-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/175852-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/145206-6-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/145206-6-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/107090-1-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/26176-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/50668-5-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/113203-5-8-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/162433-6-6-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/4918-3-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/189846-3-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/44110-3-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/155283-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/96159-4-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/189846-3-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/164626-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/207369-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/175856-1-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/162433-6-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/71309-1-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/162433-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/125520-1-3-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/33340-7-15-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/24728-7-4-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/145612-6-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/145612-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/17810-3-1-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/162433-6-2-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/83465-1-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/52284-6-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/89207-3-0-0.wav is below the min duration
# The following file /Users/prajwal/Desktop/test/UrbanSound8k/audio/fold8/4918-3-0-0.wav is below the min duration
# ...
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
import numpy as np

X_in = np.load(path_save_spectrogram +'noisy_voice_amp_db'+".npy")
X_ou = np.load(path_save_spectrogram +'voice_amp_db'+".npy")
#Model of noise to predict
X_ou = X_in - X_ou

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from U_Net_model import unet
from data_tools import scaled_in, scaled_ou

print(stats.describe(X_in.reshape(-1,1)))
print(stats.describe(X_ou.reshape(-1,1)))
X_in = scaled_in(X_in)
X_ou = scaled_ou(X_ou)
# Out:
# 2.1.0
# 2.1.0
# DescribeResult(nobs=81920000, minmax=(array([-80.]), array([3.81469727e-06])), mean=array([-42.32210151]), variance=array([246.21632288]), skewness=array([-0.25784586]), kurtosis=array([-0.12908877]))
# DescribeResult(nobs=81920000, minmax=(array([-62.98430634]), array([80.00000191])), mean=array([9.81034557]), variance=array([189.64521166]), skewness=array([1.046562]), kurtosis=array([0.68756813]))

# %%
#Check shape of spectrograms
print(X_in.shape)
print(X_ou.shape)
#Check new distribution
print(stats.describe(X_in.reshape(-1,1)))
print(stats.describe(X_ou.reshape(-1,1)))
# Out:
# (5000, 128, 128)
# (5000, 128, 128)
# DescribeResult(nobs=81920000, minmax=(array([-0.68]), array([0.92000008])), mean=array([0.07355797]), variance=array([0.09848653]), skewness=array([-0.25784586]), kurtosis=array([-0.12908877]))
# DescribeResult(nobs=81920000, minmax=(array([-0.84127203]), array([0.90243905])), mean=array([0.04646763]), variance=array([0.02820423]), skewness=array([1.046562]), kurtosis=array([0.68756813]))

# %%
#Reshape for training
X_in = X_in[:,:,:]
X_in = X_in.reshape(X_in.shape[0],X_in.shape[1],X_in.shape[2],1)
X_ou = X_ou[:,:,:]
X_ou = X_ou.reshape(X_ou.shape[0],X_ou.shape[1],X_ou.shape[2],1)

X_train, X_test, y_train, y_test = train_test_split(X_in, X_ou, test_size=0.10, random_state=42)

# %%
print(X_train.shape)
# Out:
# (4500, 128, 128, 1)

# %%
generator_nn=unet()
generator_nn.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 16) 160         input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 128, 128, 16) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 16) 2320        leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 128, 128, 16) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 16)   0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 32)   4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 64, 64, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   9248        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 64, 64, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)   0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   36928       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)   0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 16, 16, 128)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 128)  147584      leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 16, 16, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 16, 16, 128)  0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)    0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 256)    295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 8, 8, 256)    0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 256)    590080      leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 8, 8, 256)    0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8, 8, 256)    0           leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 16, 16, 256)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 128)  131200      up_sampling2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 16, 16, 128)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 256)  0           dropout[0][0]
#                                                                  leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  295040      concatenate[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 16, 16, 128)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147584      leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 16, 16, 128)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 128)  0           leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 64)   32832       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 32, 32, 64)   0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 128)  0           leaky_re_lu_5[0][0]
#                                                                  leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 64)   73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 32, 32, 64)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 64)   36928       leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 32, 32, 64)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 64)   0           leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 32)   8224        up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 64, 64, 32)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 64)   0           leaky_re_lu_3[0][0]
#                                                                  leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 32)   18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 64, 64, 32)   0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 32)   9248        leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 64, 64, 32)   0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 32) 0           leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 16) 2064        up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 128, 128, 16) 0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 32) 0           leaky_re_lu_1[0][0]
#                                                                  leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 16) 4624        concatenate_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 128, 128, 16) 0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 16) 2320        leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 128, 128, 16) 0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 2)  290         leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 128, 128, 2)  0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 1)  3           leaky_re_lu_22[0][0]
# ==================================================================================================
# Total params: 1,941,093
# Trainable params: 1,941,093
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
weights_path = '/Users/prajwal/Desktop/test/Train/weights'
checkpoint = ModelCheckpoint(weights_path+'/model_best.h5', verbose=1, monitor='val_loss',save_best_only=True, mode='auto')
history = generator_nn.fit(X_train, y_train, epochs=10, batch_size=20, shuffle=True, callbacks=[checkpoint], verbose=1, validation_data=(X_test, y_test))


#Plot training and validation loss (log scale)
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.yscale('log')
plt.title('Training and validation loss')
plt.legend()
plt.show()
# Out:
# Train on 4500 samples, validate on 500 samples
# Epoch 1/10
# 4480/4500 [============================>.] - ETA: 2s - loss: 0.0120 - mae: 0.1217
# Epoch 00001: val_loss improved from inf to 0.00958, saving model to /Users/prajwal/Desktop/test/Train/weights/model_best.h5
# 4500/4500 [==============================] - 466s 104ms/sample - loss: 0.0120 - mae: 0.1215 - val_loss: 0.0096 - val_mae: 0.1094
# Epoch 2/10
# 4480/4500 [============================>.] - ETA: 2s - loss: 0.0082 - mae: 0.0952
# Epoch 00002: val_loss improved from 0.00958 to 0.00769, saving model to /Users/prajwal/Desktop/test/Train/weights/model_best.h5
# 4500/4500 [==============================] - 468s 104ms/sample - loss: 0.0082 - mae: 0.0952 - val_loss: 0.0077 - val_mae: 0.0930
# Epoch 3/10
# 4480/4500 [============================>.] - ETA: 1s - loss: 0.0074 - mae: 0.0895
# Epoch 00003: val_loss improved from 0.00769 to 0.00703, saving model to /Users/prajwal/Desktop/test/Train/weights/model_best.h5
# 4500/4500 [==============================] - 438s 97ms/sample - loss: 0.0074 - mae: 0.0894 - val_loss: 0.0070 - val_mae: 0.0861
# Epoch 4/10
# 4480/4500 [============================>.] - ETA: 1s - loss: 0.0072 - mae: 0.0873
# Epoch 00004: val_loss did not improve from 0.00703
# 4500/4500 [==============================] - 434s 96ms/sample - loss: 0.0072 - mae: 0.0873 - val_loss: 0.0205 - val_mae: 0.1521
# Epoch 5/10
# 4480/4500 [============================>.] - ETA: 1s - loss: 0.0068 - mae: 0.0847
# Epoch 00005: val_loss did not improve from 0.00703
# 4500/4500 [==============================] - 430s 96ms/sample - loss: 0.0068 - mae: 0.0847 - val_loss: 0.0095 - val_mae: 0.1032
# Epoch 6/10
# 4480/4500 [============================>.] - ETA: 1s - loss: 0.0067 - mae: 0.0842
# Epoch 00006: val_loss did not improve from 0.00703
# 4500/4500 [==============================] - 433s 96ms/sample - loss: 0.0067 - mae: 0.0842 - val_loss: 0.0158 - val_mae: 0.1340
# Epoch 7/10
# 4480/4500 [============================>.] - ETA: 1s - loss: 0.0065 - mae: 0.0823
# Epoch 00007: val_loss did not improve from 0.00703
# 4500/4500 [==============================] - 429s 95ms/sample - loss: 0.0065 - mae: 0.0824 - val_loss: 0.0138 - val_mae: 0.1263
# Epoch 8/10
# 4480/4500 [============================>.] - ETA: 1s - loss: 0.0063 - mae: 0.0813
# Epoch 00008: val_loss did not improve from 0.00703
# 4500/4500 [==============================] - 456s 101ms/sample - loss: 0.0063 - mae: 0.0813 - val_loss: 0.0105 - val_mae: 0.1039
# Epoch 9/10
# 4480/4500 [============================>.] - ETA: 7s - loss: 0.0061 - mae: 0.0797
# Epoch 00009: val_loss did not improve from 0.00703
# 4500/4500 [==============================] - 1675s 372ms/sample - loss: 0.0061 - mae: 0.0797 - val_loss: 0.0108 - val_mae: 0.1056
# Epoch 10/10
# 4480/4500 [============================>.] - ETA: 1s - loss: 0.0061 - mae: 0.0792
# Epoch 00010: val_loss did not improve from 0.00703
# 4500/4500 [==============================] - 441s 98ms/sample - loss: 0.0061 - mae: 0.0792 - val_loss: 0.0121 - val_mae: 0.1090

# %%
import IPython.display as ipd

list_sound_array1 = []

y, sr = librosa.load('/Users/prajwal/Desktop/test/LibriSpeech/dev-clean/5338/284437/5338-284437-0010.flac', sr=sample_rate)
total_duration = librosa.get_duration(y=y, sr=sr)
    
if (total_duration >= min_duration):
            list_sound_array1.append(audio_to_audio_frame_stack(
                y, frame_length, hop_length_frame))
else:
    print(f"The following file {os.path.join(audio_dir,file)} is below the min duration")

voice = np.vstack(list_sound_array1)

ipd.Audio(data = y,rate = sr)
# Out:
# /Users/prajwal/Anaconda/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
list_sound_array2 = []
y, sr = librosa.load('/Users/prajwal/Desktop/test/UrbanSound8K/audio/fold5/100852-0-0-0.wav', sr=sample_rate)
total_duration = librosa.get_duration(y=y, sr=sr)
    
if (total_duration >= min_duration):
            list_sound_array2.append(audio_to_audio_frame_stack(
                y, frame_length, hop_length_frame))
else:
    print(f"The following file {os.path.join(audio_dir,file)} is below the min duration")
noise = np.vstack(list_sound_array2)
ipd.Audio('/Users/prajwal/Desktop/test/UrbanSound8K/audio/fold2/204773-3-9-0.wav')
ipd.Audio(data = y,rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(voice.shape)
print(noise.shape)
# Out:
# (6, 8064)
# (3, 8064)

# %%
from data_tools import blend_noise_randomly
voice, noise, voice_with_noise = blend_noise_randomly(voice, noise, 1, frame_length)

# %%
ipd.Audio(data = voice,rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(data = noise,rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(data = voice_with_noise, rate = sr )
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from data_tools import numpy_audio_to_matrix_spectrogram
# Squared spectrogram dimensions
dim_square_spec = int(n_fft / 2) + 1

# Create Amplitude and phase of the sounds
m_amp_db_voice,  m_pha_voice = numpy_audio_to_matrix_spectrogram(voice, dim_square_spec, n_fft, hop_length_fft)
m_amp_db_noise,  m_pha_noise = numpy_audio_to_matrix_spectrogram(noise, dim_square_spec, n_fft, hop_length_fft)
m_amp_db_noisy_voice,  m_pha_noisy_voice = numpy_audio_to_matrix_spectrogram(voice_with_noise, dim_square_spec, n_fft, hop_length_fft)

# %%
X_check = m_amp_db_noisy_voice
X_check = scaled_in(X_check)

X_check = X_check[:,:,:]
X_check = X_check.reshape(X_check.shape[0],X_check.shape[1],X_check.shape[2],1)

print(X_check[0].shape)

Y_pred = generator_nn.predict(X_check)
# Out:
# (128, 128, 1)

# %%
from data_tools import scaled_in, inv_scaled_ou

inv_sca_Y_pred = inv_scaled_ou(Y_pred)
X_denoise = m_amp_db_noisy_voice - inv_sca_Y_pred[:,:,:,0]
print(X_denoise.shape)
# Out:
# (1, 128, 128)

# %%
from data_tools import matrix_spectrogram_to_numpy_audio
audio_denoise_recons = matrix_spectrogram_to_numpy_audio(X_denoise, m_pha_noisy_voice, frame_length, hop_length_fft)
nb_samples = audio_denoise_recons.shape[0]
denoise_long = audio_denoise_recons.reshape(1, nb_samples * frame_length)*10

# %%
ipd.Audio(data = denoise_long[0, :], rate = sr )
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa.display
def make_3plots_spec_voice_noise(stftvoicenoise_mag_db,stftnoise_mag_db,stftvoice_mag_db,sample_rate, hop_length_fft):
    """This function plots the spectrograms of noisy voice, noise and voice as a single plot """
    plt.figure(figsize=(8, 12))
    plt.subplot(3, 1, 1)
    plt.title('Spectrogram voice + noise')
    librosa.display.specshow(stftvoicenoise_mag_db, x_axis='time', y_axis='linear',sr=sample_rate, hop_length=hop_length_fft)
    plt.colorbar()
    plt.subplot(3, 1, 2)
    plt.title('Spectrogram predicted voice')
    librosa.display.specshow(stftnoise_mag_db, x_axis='time', y_axis='linear',sr=sample_rate, hop_length=hop_length_fft)
    plt.colorbar()
    plt.subplot(3, 1, 3)
    plt.title('Spectrogram true voice')
    librosa.display.specshow(stftvoice_mag_db, x_axis='time', y_axis='linear',sr=sample_rate, hop_length=hop_length_fft)
    plt.colorbar()
    plt.tight_layout()

    return

# %%
'''
y, sr = librosa.load('/Users/prajwal/Desktop/test/output/noised_voice.wav', sr=sample_rate)
noised_voice_stft = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)

y, sr = librosa.load('/Users/prajwal/Desktop/test/output/denoised_predicted.wav', sr=sample_rate)
denoised_voice_stft = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)

y, sr = librosa.load('/Users/prajwal/Desktop/test/output/actual_voice.wav', sr=sample_rate)
actual_voice_stft = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)



make_3plots_spec_voice_noise(noised_voice_stft, denoised_voice_stft, actual_voice_stft, sample_rate, hop_length_fft)
'''
# Out:
# "\ny, sr = librosa.load('/Users/prajwal/Desktop/test/output/noised_voice.wav', sr=sample_rate)\nnoised_voice_stft = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)\n\ny, sr = librosa.load('/Users/prajwal/Desktop/test/output/denoised_predicted.wav', sr=sample_rate)\ndenoised_voice_stft = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)\n\ny, sr = librosa.load('/Users/prajwal/Desktop/test/output/actual_voice.wav', sr=sample_rate)\nactual_voice_stft = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)\n\n\n\nmake_3plots_spec_voice_noise(noised_voice_stft, denoised_voice_stft, actual_voice_stft, sample_rate, hop_length_fft)\n"
